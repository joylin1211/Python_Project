# %%
# 資料結構

# %%
#List
#可以修改

scores=[89,92,76,91,88]
print(scores)
# Out:
# [89, 92, 76, 91, 88]

# %%
# Tuple
# Tuple建立後不可以修改內容
# Read only
# 何時使用?? 暫時儲存

scores1=(89,92,76,91,88)
print(scores1)
# Out:
# (89, 92, 76, 91, 88)
