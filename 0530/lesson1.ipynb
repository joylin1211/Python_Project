# %%
# 資料結構

# %%
#List
#可以修改
#scores[1]這個叫subscript

scores=[89,92,76,91,88]
print(scores)
print(scores[0])
print(scores[1])
print(scores[2])
print(scores[3])
print(scores[4])
scores[0]=100
print(scores)
# Out:
# [89, 92, 76, 91, 88]
# 89
# 92
# 76
# 91
# 88
# [100, 92, 76, 91, 88]

# %%
# Tuple
# Tuple建立後不可以修改內容，read only
# Read only
# 何時使用?? 暫時儲存

scores1=(89,92,76,91,88)
print(scores1)
print(scores1[0])
print(scores1[1])
print(scores1[2])
print(scores1[3])
print(scores1[4])
#scores1[0]=100
#print(scores1)
# Out:
# (89, 92, 76, 91, 88)
# 89
# 92
# 76
# 91
# 88

# %%
# List

score=[100,90,80]
print(score)
print(score[0])
print(score[1])
print(score[2])
score[0]=120
print(score)
# Out:
# [100, 90, 80]
# 100
# 90
# 80
# [120, 90, 80]

# %%
#Tuple

score=(100,90,80)
print(score)
print(score[0])
print(score[1])
print(score[2])

#錯誤!因為Tuple不可以修改是read only
#score[0]=120
#print(score)
# Out:
# (100, 90, 80)
# 100
# 90
# 80

# %%
# dictionary

students = {'chinese': 90, 'english': 70, 'math': 60}

print(students)
print('chinese score:', students['chinese'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 5
#       1 #dictionary
#       2
#       3 students={'chinese':90,'english':70,'math':60}
#       4
# ----> 5 print(students)
#
# TypeError: 'int' object is not callable

# %%
students = {
	'chinese':89,
	'english':94,
	'math':65,
	'history':92,
	'discover': 95}
print(students)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 7
#       3         'english':94,
#       4         'math':65,
#       5         'history':92,
#       6         'discover': 95}
# ----> 7 print(students)
#
# TypeError: 'int' object is not callable
